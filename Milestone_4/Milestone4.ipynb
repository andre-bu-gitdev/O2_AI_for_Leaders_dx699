# %% [markdown]
# ## Milestone 4 Notebook

# %% [markdown]
# ### Week 1-7

# %% [markdown]
# #### 🔢 Univariate Functions

# %%
# Week 1
df = pd.DataFrame([[1, 4], [2, 5], [3, 6], [4, 7]], columns = ['A', 'B'])
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Week 1
# ----> 2 df = pd.DataFrame([[1, 4], [2, 5], [3, 6], [4, 7]], columns = ['A', 'B'])
#       3 df.describe()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# #### 🔢 Bivariate Functions

# %%
# code
